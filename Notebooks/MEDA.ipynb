# %%
import sys 
sys.path.append('../src')
from db_connection import conn
#public libs
import pandas as pd
import matplotlib as plt

# %%
#Load the dataset until sql
q = 'SELECT * FROM criminal_mind_raw'
df_raw = pd.read_sql(sql=q, con=conn.engine)

# %% [markdown]
# UBICACION Y CONTEXTO

# %%
df_raw.keys()
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
list_col = ['Date Rptd', 'DR_NO', 'DATE OCC', 'TIME OCC', 'Crm Cd Desc', 'Weapon Used Cd', 'Weapon Desc']

# %%
df_raw[['Crm Cd', 'Crm Cd Desc', 'Mocodes']].head(10)
# Out:
#    Crm Cd                               Crm Cd Desc              Mocodes
# 0     510                          VEHICLE - STOLEN                 None
# 1     330                     BURGLARY FROM VEHICLE       1822 1402 0344
# 2     480                             BIKE - STOLEN            0344 1251
# 3     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)            0325 1501
# 4     354                         THEFT OF IDENTITY  1822 1501 0930 2004
# 5     354                         THEFT OF IDENTITY  1822 0100 0930 0929
# 6     354                         THEFT OF IDENTITY            0930 0929
# 7     354                         THEFT OF IDENTITY                 0100
# 8     354                         THEFT OF IDENTITY                 0100
# 9     624                  BATTERY - SIMPLE ASSAULT                 0416

# %%
df_raw[['Crm Cd', 'Crm Cd Desc', 'Mocodes', 'Weapon Used Cd', 'Weapon Desc']].head(10)
# Out:
#    Crm Cd                               Crm Cd Desc              Mocodes  \
# 0     510                          VEHICLE - STOLEN                 None
# 1     330                     BURGLARY FROM VEHICLE       1822 1402 0344
# 2     480                             BIKE - STOLEN            0344 1251
# 3     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)            0325 1501
# 4     354                         THEFT OF IDENTITY  1822 1501 0930 2004
# 5     354                         THEFT OF IDENTITY  1822 0100 0930 0929
# 6     354                         THEFT OF IDENTITY            0930 0929
# 7     354                         THEFT OF IDENTITY                 0100
# 8     354                         THEFT OF IDENTITY                 0100
# 9     624                  BATTERY - SIMPLE ASSAULT                 0416
#
#    Weapon Used Cd                                     Weapon Desc
# 0             NaN                                            None
# ...

# %%
df_raw['Weapon Desc'].unique().__len__()
# Out:
# 80

# %%
df_raw['Weapon Used Cd'].unique().__len__()
# Out:
# 80

# %%
df_raw.keys()
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
list_col = ['Crm Cd','Status', 'Status Desc', 'LON', 'LAT', 'LOCATION', 'Cross Street', 'AREA NAME']

# %%
df_raw[list_col]
# Out:
#         Crm Cd Status   Status Desc       LON      LAT  \
# 0          510     AA  Adult Arrest -118.3506  34.0375
# 1          330     IC   Invest Cont -118.2628  34.0444
# 2          480     IC   Invest Cont -118.3002  34.0210
# 3          343     IC   Invest Cont -118.4387  34.1576
# 4          354     IC   Invest Cont -118.3277  34.0944
# ...        ...    ...           ...       ...      ...
# 966946     624     IC   Invest Cont -118.3054  34.0690
# 966947     510     IC   Invest Cont -118.3284  34.0362
# 966948     745     IC   Invest Cont -118.2460  34.0685
# 966949     888     IC   Invest Cont -118.5990  34.2500
# 966950     230     IC   Invest Cont -118.2868  34.0215
#
#                                         LOCATION  \
# 0        1900 S  LONGWOOD                     AV
# 1        1000 S  FLOWER                       ST
# 2        1400 W  37TH                         ST
# 3       14000    RIVERSIDE                    DR
# 4                              1900    TRANSIENT
# ...

# %%
df_raw[list_col].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966951 entries, 0 to 966950
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Crm Cd        966951 non-null  int64
#  1   Status        966950 non-null  object
#  2   Status Desc   966951 non-null  object
#  3   LON           966951 non-null  float64
#  4   LAT           966951 non-null  float64
#  5   LOCATION      966951 non-null  object
#  6   Cross Street  150218 non-null  object
#  7   AREA NAME     966951 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 59.0+ MB

# %%
df_raw['AREA NAME'].unique()
# Out:
# array(['Wilshire', 'Central', 'Southwest', 'Van Nuys', 'Hollywood',
#        'Southeast', 'Newton', 'Mission', 'Rampart', 'West Valley',
#        'West LA', '77th Street', 'Olympic', 'Hollenbeck', 'Topanga',
#        'Northeast', 'Pacific', 'N Hollywood', 'Harbor', 'Foothill',
#        'Devonshire'], dtype=object)

# %%
df_raw['Status'].unique()
# Out:
# array(['AA', 'IC', 'JA', 'AO', 'JO', 'CC', None], dtype=object)

# %%
df_raw['Status Desc'].unique()
# Out:
# array(['Adult Arrest', 'Invest Cont', 'Juv Arrest', 'Adult Other',
#        'Juv Other', 'UNK'], dtype=object)

# %%
df_raw['Cross Street'].isna().value_counts()
# Out:
# Cross Street
# True     816733
# False    150218
# Name: count, dtype: int64

# %% [markdown]
# Just 2% NOT NULLS

# %%
df_raw['LOCATION'].isna().value_counts()
# Out:
# LOCATION
# False    966951
# Name: count, dtype: int64

# %% [markdown]
# NOT NULLS

# %%
df_raw[~df_raw['Cross Street'].isna()]
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 13      221008844  05/06/2022 12:00:00 AM  11/01/2020 12:00:00 AM       130
# 34      221404806  01/19/2022 12:00:00 AM  01/18/2020 12:00:00 AM      1600
# 60      220104934  01/17/2022 12:00:00 AM  12/20/2020 12:00:00 AM      1730
# 78      201810154  04/26/2020 12:00:00 AM  04/22/2020 12:00:00 AM      1900
# 89      220313293  07/06/2022 12:00:00 AM  06/30/2020 12:00:00 AM      1400
# ...           ...                     ...                     ...       ...
# 966929  241807402  03/12/2024 12:00:00 AM  03/12/2024 12:00:00 AM       630
# 966932  241304056  01/02/2024 12:00:00 AM  01/01/2024 12:00:00 AM      2100
# 966939  240405919  02/27/2024 12:00:00 AM  02/26/2024 12:00:00 AM      1545
# 966946  242004546  01/16/2024 12:00:00 AM  01/16/2024 12:00:00 AM      1510
# 966950  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
#
# ...

# %%
df_raw[~df_raw['Cross Street'].isna()].describe(include='object')
# Out:
#                      Date Rptd                DATE OCC AREA NAME  \
# count                   150218                  150218    150218
# unique                    1679                    1679        21
# top     06/11/2020 12:00:00 AM  05/30/2020 12:00:00 AM   Central
# freq                       137                     246     15011
#
#              Crm Cd Desc Mocodes Vict Sex Vict Descent Premis Desc  \
# count             150218  125053   125635       125632      150199
# unique               128   73058        4           19         288
# top     VEHICLE - STOLEN    0344        M            H      STREET
# freq               21190    4070    68263        54247       88279
#
#                                            Weapon Desc  Status  Status Desc  \
# count                                            75321  150218       150218
# unique                                              79       6            6
# ...

# %%
df_raw.describe(include='object')
# Out:
#                      Date Rptd                DATE OCC AREA NAME  \
# count                   966951                  966951    966951
# unique                    1679                    1679        21
# top     02/03/2023 12:00:00 AM  01/01/2020 12:00:00 AM   Central
# freq                       925                    1151     66233
#
#              Crm Cd Desc Mocodes Vict Sex Vict Descent Premis Desc  \
# count             966951  826575   833245       833235      966375
# unique               139  308341        5           20         306
# top     VEHICLE - STOLEN    0344        M            H      STREET
# freq              107349   39874   392382       290142      248363
#
#                                            Weapon Desc  Status  Status Desc  \
# count                                           325476  966950       966951
# unique                                              79       6            6
# ...

# %%
dfuc = df_raw[list_col]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966951 entries, 0 to 966950
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           966951 non-null  int64
#  1   Date Rptd       966951 non-null  object
#  2   DATE OCC        966951 non-null  object
#  3   TIME OCC        966951 non-null  int64
#  4   AREA            966951 non-null  int64
#  5   AREA NAME       966951 non-null  object
#  6   Rpt Dist No     966951 non-null  int64
#  7   Part 1-2        966951 non-null  int64
#  8   Crm Cd          966951 non-null  int64
#  9   Crm Cd Desc     966951 non-null  object
#  10  Mocodes         826575 non-null  object
#  11  Vict Age        966951 non-null  int64
#  12  Vict Sex        833245 non-null  object
#  13  Vict Descent    833235 non-null  object
#  14  Premis Cd       966937 non-null  float64
#  15  Premis Desc     966375 non-null  object
# ...

# %%
df_raw['Mocodes'].unique().__len__()
# Out:
# 308342

# %%
# Out:
# Empty DataFrame
# Columns: [DR_NO, Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Rpt Dist No, Part 1-2, Crm Cd, Crm Cd Desc, Mocodes, Vict Age, Vict Sex, Vict Descent, Premis Cd, Premis Desc, Weapon Used Cd, Weapon Desc, Status, Status Desc, Crm Cd 1, Crm Cd 2, Crm Cd 3, Crm Cd 4, LOCATION, Cross Street, LAT, LON]
# Index: []
#
# [0 rows x 28 columns]

# %%
df_raw[df_raw['Vict Sex'].isna()][['AREA NAME', 'Status', 'Status Desc', 'Weapon Desc']].describe(include='object')
# Out:
#           AREA NAME  Status  Status Desc  \
# count        133706  133705       133706
# unique           21       6            6
# top     77th Street      IC  Invest Cont
# freq           9366  126458       126458
#
#                                            Weapon Desc
# count                                               72
# unique                                              17
# top     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# freq                                                31

# %%
df_raw[df_raw['Vict Sex'].isna() & ~(df_raw['Status']=='IC')][['AREA NAME', 'Status', 'Status Desc', 'Weapon Desc']].describe(include='object')
# Out:
#         AREA NAME Status   Status Desc  \
# count        7248   7247          7248
# unique         21      5             5
# top     Southwest     AA  Adult Arrest
# freq          579   4502          4502
#
#                                            Weapon Desc
# count                                               29
# unique                                              14
# top     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# freq                                                10

# %%
df_raw[df_raw['Vict Sex'].isna() & ~(df_raw['Status']=='IC')]['Status'].unique()
# Out:
# array(['AA', 'AO', 'JA', 'JO', 'CC', None], dtype=object)
