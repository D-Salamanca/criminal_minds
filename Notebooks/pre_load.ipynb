# %%
import sys
import pandas as pd
sys.path.append('../src')
from db_connection import conn

# %%
#Load the data in a dataframe object
df = pd.read_csv('../Data/Crime_Data_from_2020_to_Present_20240818.csv')
#Load the data into a SQL DATABASE
df.to_sql(name='criminal_mind_raw', con=conn.engine.connect(), if_exists='replace', index=False)  #name = Table Name
                                                                                        #con = connection to the database
                                                                                        #index = keep the pandas indexes
# Out:
# 638

# %%
#Read the data until POSTGRES

#Query to get the data
q = 'Select * from criminal_mind_raw'
#Read until postgresql
df_postgres = pd.read_sql(sql=q, con=conn.engine)

# %%
df_postgres.shape
# Out:
# (982638, 28)

# %%
df_postgres.head(5)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...
